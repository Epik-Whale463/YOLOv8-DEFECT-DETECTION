# %%
import torch
print(torch.cuda.is_available())  # Should print True if CUDA is working
print(torch.cuda.current_device())  # Should print the CUDA device ID
print(torch.cuda.get_device_name(torch.cuda.current_device()))  # Device name
# Out:
# True
# 0
# Tesla P100-PCIE-16GB

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs

# %%
from ultralytics import YOLO
import os
import torch

data_yaml_path = "/kaggle/input/metallic-surface-defect/data.yaml"

model = YOLO("yolov8n.pt")

device = 'cuda' if torch.cuda.is_available() else 'cpu'

model.train(
    data=data_yaml_path,
    epochs=50,
    imgsz=640,
    batch=16,
    project=".",
    name="train8",
    device=device
)


from ultralytics.yolo.utils import LOGGER
from ultralytics.utils.plotting import plot_results

results_dir = os.path.join(current_dir, "train8")

plot_results(save_dir=results_dir)

LOGGER.info(f"Training curves saved to {results_dir}")
# Out:
# Ultralytics 8.3.128 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from IPython.display import Image, display
display(Image(filename=os.path.join(results_dir, "results.png")))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-dba9ce4e1e58> in <cell line: 2>()
#       1 from IPython.display import Image, display
# ----> 2 display(Image(filename=os.path.join(results_dir, "results.png")))
#
# NameError: name 'results_dir' is not defined
